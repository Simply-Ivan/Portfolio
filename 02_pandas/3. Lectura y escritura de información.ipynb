# %%
import numpy as np
import pandas as pd

# %%
# Ruta relativa en el directorio actual
tienda = pd.read_csv('Organization_v2.csv', nrows = 10)
tienda
# Out:
#    Unnamed: 0.1  Unnamed: 0 organization.organizationIdentifier     orgType  \
# 0             0           0                           LightTree  OPERATIONS
# 1             1           1                                 FAA    CUSTOMER
# 2             2           2                                COLA    CUSTOMER
# 3             3           3                                QPWD    CUSTOMER
# 4             4           4                                MAHD    CUSTOMER
# 5             5           5                                KYTC    CUSTOMER
# 6             6           6                               NYDOT    CUSTOMER
# 7             7           7                             CALTRAN    CUSTOMER
# 8             8           8                                AHTD    CUSTOMER
# 9             9           9                           Alumi-lux    SUPPLIER
#
#   location.locationIdentifier  \
# 0                        LT-1
# 1            FAA - Washington
# 2           COLA - Los Alamos
# ...

# %%
# Ruta relativa dentro de una carpeta
tienda2 = pd.read_csv('dato/Shipment_v4.csv')
tienda2.head()
# Out:
#   shipmentIdentifier shipmentType shipFromLocation.locationIdentifier  \
# 0            3004555     OUTBOUND                                LT-1
# 1            3004554     OUTBOUND                                LT-1
# 2            3004553     OUTBOUND                                LT-1
# 3            3004552     OUTBOUND                                LT-1
# 4            3004549     OUTBOUND                                LT-1
#
#   shipToLocation.locationIdentifier vendor.organizationIdentifier  \
# 0              NYDOT - New Rochelle                     LightTree
# 1              NYDOT - New Rochelle                     LightTree
# 2              NYDOT - New Rochelle                     LightTree
# 3              NYDOT - New Rochelle                     LightTree
# 4               CALTRAN - San Diego                     LightTree
#
#   buyer.organizationIdentifier carrier.organizationIdentifier  status  \
# 0                        NYDOT                         TranEx     NaN
# ...

# %%
# Ruta relativa antes del directorio actual
tienda3 = pd.read_csv('../dato2/Catalog_v2.csv', nrows = 6)
tienda3
# Out:
#   levelType                  code catalogType                  name  \
# 0  CATEGORY       Street Lighting     PRODUCT       Street Lighting
# 1  CATEGORY   Pedestrian Lighting     PRODUCT   Pedestrian Lighting
# 2  CATEGORY  Traffic Signal Poles     PRODUCT  Traffic Signal Poles
# 3  CATEGORY              Controls     PRODUCT              Controls
# 4  CATEGORY            Downlights     PRODUCT            Downlights
# 5  CATEGORY   Retrofit Downlights     PRODUCT   Retrofit Downlights
#
#                               description  \
# 0       Category code for Street Lighting
# 1   Category code for Pedestrian Lighting
# 2  Category code for Traffic Signal Poles
# 3              Category code for Controls
# 4            Category code for Downlights
# 5   Category code for Retrofit Downlights
#
#                                   sourceLink
# 0       http://lighttree.com/Street Lighting
# 1   http://lighttree.com/Pedestrian Lighting
# 2  http://lighttree.com/Traffic Signal Poles
# ...

# %%
# Ruta absoluta con '/'
tienda4 = pd.read_csv('C:/Users/ASUS/Programación/Ciencia de datos/Pandas/Product_v5.csv', nrows = 6)
tienda4
# Out:
#    partNumber productType    category.code     brand.code      family.code  \
# 0  PS-SL-A287     PRODUCT  Street Lighting  Public Sector         Alliance
# 1  PS-SL-A288     PRODUCT  Street Lighting  Public Sector         Alliance
# 2  PS-SL-H309     PRODUCT  Street Lighting  Public Sector             Helm
# 3  PS-SL-H310     PRODUCT  Street Lighting  Public Sector             Helm
# 4  PS-SL-F342     PRODUCT  Street Lighting  Public Sector  Flatbush Avenue
# 5  PS-SL-F343     PRODUCT  Street Lighting  Public Sector  Flatbush Avenue
#
#   line.code  segment.code  status   value valueCurrency defaultQuantityUnits  \
# 0     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 1     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 2     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 3     Rural           NaN  ACTIVE  1250.0          USD                   EA
# ...

# %%
# Ruta absoluta con '\\'
tienda4 = pd.read_csv('C:\\Users\\ASUS\\Programación\\Ciencia de datos\\Pandas\\Product_v5.csv', nrows = 6)
tienda4
# Out:
#    partNumber productType    category.code     brand.code      family.code  \
# 0  PS-SL-A287     PRODUCT  Street Lighting  Public Sector         Alliance
# 1  PS-SL-A288     PRODUCT  Street Lighting  Public Sector         Alliance
# 2  PS-SL-H309     PRODUCT  Street Lighting  Public Sector             Helm
# 3  PS-SL-H310     PRODUCT  Street Lighting  Public Sector             Helm
# 4  PS-SL-F342     PRODUCT  Street Lighting  Public Sector  Flatbush Avenue
# 5  PS-SL-F343     PRODUCT  Street Lighting  Public Sector  Flatbush Avenue
#
#   line.code  segment.code  status   value valueCurrency defaultQuantityUnits  \
# 0     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 1     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 2     Rural           NaN  ACTIVE  1250.0          USD                   EA
# 3     Rural           NaN  ACTIVE  1250.0          USD                   EA
# ...

# %%
ejemplo = pd.read_csv('Organization_v2.csv', sep=',')
ejemplo.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 organization.organizationIdentifier     orgType  \
# 0             0           0                           LightTree  OPERATIONS
# 1             1           1                                 FAA    CUSTOMER
# 2             2           2                                COLA    CUSTOMER
# 3             3           3                                QPWD    CUSTOMER
# 4             4           4                                MAHD    CUSTOMER
#
#   location.locationIdentifier  \
# 0                        LT-1
# 1            FAA - Washington
# 2           COLA - Los Alamos
# 3      QPWD - Ville de Québec
# 4               MAHD - Boston
#
#                                               name  division  \
# 0                                        LightTree       NaN
# 1            Federal Aviation Administration (FAA)       NaN
# 2                               City of Los Alamos       NaN
# 3                   Quebec Public Works Department       NaN
# ...

# %%
ejemplo.to_csv('Organization_v2.csv', sep=',')

# %%
ejemplo = pd.read_csv('Organization_v2.csv', sep=',')
ejemplo.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 organization.organizationIdentifier  \
# 0             0             0           0                           LightTree
# 1             1             1           1                                 FAA
# 2             2             2           2                                COLA
# 3             3             3           3                                QPWD
# 4             4             4           4                                MAHD
#
#       orgType location.locationIdentifier  \
# 0  OPERATIONS                        LT-1
# 1    CUSTOMER            FAA - Washington
# 2    CUSTOMER           COLA - Los Alamos
# 3    CUSTOMER      QPWD - Ville de Québec
# 4    CUSTOMER               MAHD - Boston
#
#                                               name  division  \
# 0                                        LightTree       NaN
# 1            Federal Aviation Administration (FAA)       NaN
# ...
